# %% [markdown]
# # The Expanding Universe

# %% [markdown]
# # I have prepared the data from Wikipedia and formed a dataframe for the analysis of the expansion of the universe.
#
# # I have Studied the Relationship between Redshift (z) Values and Distance of Astronomical Objects.
#
# # In 1929, Edwin Hubble demonstrated that galaxy clusters and other astronomical objects are moving away from us. According to the Doppler effect, galaxies moving away from each other cause a stretching of the wavelengths of light emitted by these galaxies, shifting them toward the longer-wavelength, lower-energy end of the electromagnetic spectrum. This shift is observed as a displacement of spectral lines toward the red end and is known as cosmological redshift.
#
# # Redshift values indicate that the incoming electromagnetic radiation from distant stars and galaxies reaches the Earth with their spectra shifted towards the red end of the spectrum. This shift occurs because as space expands, electromagnetic waves have to travel a greater distance to reach Earth.
#
# # If galaxies were moving towards each other, then the incoming spectra would shift towards the blue end of the spectrum. However, Sir Edwin Hubble observed the opposite phenomenon.
#
# # In summary, the larger the redshift, the greater the distance, and the faster the galaxy is moving away from us.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Different Astronomical Objects and Thier Redshift Values

# %%
df=pd.read_excel(r"C:\Users\patel\Documents\Msc_AA_2nd_sem\1st_module\project\data\galaxy_clusters_final.xlsx")

# %%
df.head()
# Out:
#   Image            Name  Redshift  Light Years Distance    Type  \
# 0   NaN  JADES-GS-z13-0     13.20                13.576  Galaxy
# 1   NaN  JADES-GS-z12-0     12.63                13.556  Galaxy
# 2   NaN  JADES-GS-z11-0     11.58                13.512  Galaxy
# 3   NaN          GN-z11     10.95                13.481  Galaxy
# 4   NaN   UDFj-39546284     10.38                13.449  Galaxy
#
#                                                Notes
# 0  Lyman-break galaxy, detection of the Lyman bre...
# 1  Lyman-break galaxy, detection of the Lyman bre...
# 2  Lyman-break galaxy, detection of the Lyman bre...
# 3  Lyman-break galaxy; detection of the Lyman bre...
# 4  Lyman-break galaxy, detection of the Lyman bre...

# %%
#extracting the columns
a=df.loc[:,"Redshift"]
b=df.loc[:,"Light Years Distance"]
c=df.loc[:,"Name"]

# %%
#converting columns into the array
redshift=np.array(a)
distance=np.array(b)
name=np.array(c)
redshift
distance
name
# Out:
# array(['JADES-GS-z13-0', 'JADES-GS-z12-0', 'JADES-GS-z11-0', 'GN-z11',
#        'UDFj-39546284', 'JD1', 'MACS1149-JD1', 'EGSY8p7', 'SMACS-4590',
#        'A2744_YD4', 'MACS0416_Y1', 'GRB 090423', 'EGS-zs8-1',
#        'SMACS-6355', 'z7_GSD_3811', 'SMACS-10612', 'J0313–1806',
#        'ULAS J1342+0928', 'z8_GND_5296', 'A1689-zD1', 'GS2_1406',
#        'GN-108036', 'SXDF-NB1006-2', 'BDF-3299', 'ULAS J1120+0641',
#        'A1703_zD6', 'BDF-521', 'G2_1408', 'IOK-1',
#        'LAE J095950.99+021219.1', 'SDF-46975', 'PSO J172.3556+18.7734',
#        nan], dtype=object)

# %%
#ploting the point graph of redshift values and thier distances
plt.figure(figsize=(12,7))
plt.scatter(redshift,distance,color="black")
plt.title("Relationship of Redshift Values with Distance (Light Years)",fontsize=20)
plt.xlabel("Redshift(z)",weight="bold")
plt.ylabel("Distance(light years)",weight="bold")
plt.legend(["Redshift(Expanding Rate)(z)"])
plt.savefig("Expanding universe_001")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.plot(distance,redshift,color='blue',marker='.',markersize=20,markeredgecolor='red',markerfacecolor='red')
plt.title("Distant Astronomical objects with their Redshift Values",fontsize=20,color='black')
plt.xlabel("Distance(light year)",weight="bold")
plt.ylabel("Redshift(z)",weight="bold")
plt.legend(["Redshift(Expanding Rate)(z)"],loc='upper left')
plt.savefig("Expanding universe_002")
plt.grid()
plt.show()

# %%
print(redshift)
print(distance)
# Out:
# [13.2   12.63  11.58  10.95  10.38   9.756  9.109  8.683  8.496  8.38
#   8.311  8.23   7.73   7.665  7.663  7.658  7.642  7.541  7.51   7.5
#   7.452  7.213  7.212  7.109  7.085  7.045  7.008  6.972  6.965  6.944
#   6.844  6.8      nan]
# [13.576 13.556 13.512 13.481 13.449 13.409 13.361 13.325 13.308 13.297
#  13.29  13.282 13.228 13.221 13.221 13.221 13.218 13.206 13.202 13.201
#  13.195 13.164 13.164 13.149 13.146 13.14  13.135 13.13  13.129 13.126
#  13.111 13.107    nan]

# %%
redshift.sort()
distance.sort()

# %%
plt.figure(figsize=(15,15))
plt.plot(redshift,distance,color='black',linestyle='--',marker='.',markersize=20,markeredgecolor='blue')
plt.title("Astronomical Objcet's Redshift and Distance Values",fontsize=20,color='red')
plt.xlabel("Redshift(z)",weight="bold")
plt.ylabel("Distance (Light Years)",weight="bold")
plt.legend(["Redshift (Expanding Rate)(z)"])
plt.savefig("Expanding Universe_003")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(18,15))
bar=plt.bar(distance,redshift)
bar[0].set_hatch('/')
bar[30].set_hatch('*')
bar[31].set_hatch('*')
plt.title("Distant Astronomical objects Behaviour of Redshift Values with Distance (Light Years)",fontsize=20,color='black')
plt.xlabel("Redshift(z)",weight="bold")
plt.ylabel("Distance(Light Years)",weight="bold")
plt.legend(["Redshift(z)"])
plt.grid()
plt.show()

# %% [markdown]
# # Different Constellations and thier Redshift Values

# %%
con=pd.read_excel(r"C:\Users\patel\Documents\Msc_AA_2nd_sem\1st_module\project\data\Constellation_redshift_values.xlsx")

# %%
data_1=con.rename(columns={'z':'Redshift Value(z)','cluster':'Astronomical Clusters'})
data_1
# Out:
#          RA      Dec Astronomical Clusters  Redshift Value(z)  \
# 0  186.8055  12.7350                 Virgo              0.006
# 1  195.2171  28.3661                  Coma              0.025
# 2  231.5741  28.9272       Corona Borealis              0.074
# 3  164.6540  56.8640       Ursa Majoris II              0.138
# 4  177.8001  55.2883        Ursa Majoris I              0.153
# 5  217.1976  31.8846                Bootes              0.197
# 6    2.8806   0.2560                  none              0.505
# 7  142.5426   0.3472                  none              1.077
#
#   link to original spectrum link to smoothed spectrum  \
# 0             SDSS spectrum         smoothed spectrum
# 1             SDSS spectrum         smoothed spectrum
# 2             SDSS spectrum         smoothed spectrum
# 3             SDSS spectrum         smoothed spectrum
# 4             SDSS spectrum         smoothed spectrum
# 5             SDSS spectrum         smoothed spectrum
# ...

# %%
#dropping the nan value columns
data_2=data_1.drop([6,7],axis=0)

# %%
#extracting the columns from dataframe
z=data_2.loc[:,"Astronomical Clusters"]
n=data_2.loc[:,"Redshift Value(z)"]

# %%
#converting the data into array
cluster_name=np.array(z)
redshift_values=np.array(n)

# %%
print(redshift_values)
print(cluster_name)
# Out:
# [0.006 0.025 0.074 0.138 0.153 0.197]
# ['Virgo' 'Coma' 'Corona Borealis' 'Ursa Majoris II' 'Ursa Majoris I'
#  'Bootes']

# %%
plt.figure(figsize=(12, 8))
plt.plot(cluster_name,redshift_values,linewidth=3,color='red',marker='*',markersize=20,markeredgecolor='black')
plt.title("Distant Atronomical Clusters",fontsize=20,color='green')
plt.xlabel("cluster_name",weight="bold")
plt.ylabel("redshift_values(z)",weight="bold")
plt.legend(["Redshift(z)"])
plt.savefig("expanding universe_004")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.bar(cluster_name,redshift_values,color='red')
plt.title("Distant Atronomical Clusters and Behaviour of thier Redshift Values",fontsize=20,color='green')
plt.xlabel("Cluster Names",weight="bold")
plt.ylabel("Redshift Values",weight="bold")
plt.legend(["Redshift(z)"])
plt.savefig("Expanding universe_005")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(cluster_name,redshift_values,color='b')
plt.title("Distant Astronomical Cluster's Names with Redshift Values",fontsize=20,color='green')
plt.xlabel("Cluster Names",weight="bold")
plt.ylabel("Redshift Values",weight="bold")
plt.legend(["Redshift value(z)"])
plt.savefig("Expanding universe_006")
plt.grid()
plt.show()

# %% [markdown]
# # Stars and thier Redshift values

# %%
stars=pd.read_excel(r"C:\Users\patel\Documents\Msc_AA_2nd_sem\1st_module\project\data\Stars_Redshift.xlsx")
stars
# Out:
#                    Star Name  Redshift      mas      parsic   Light Year
# 0            LSPM J1247+0646   3.63758  19.0575   52.472780   171.061262
# 1   SDSS J154213.47+034800.4   2.73313   6.8147  146.741603   478.377625
# 2                   EGGR 561   2.72013  18.3113   54.611087   178.032144
# 3             KUV 03292+0035   2.71708   9.0273  110.775093   361.126804
# 4   SDSS J083226.57+370955.4   2.26700   8.4573  118.241046   385.465811
# 5   SDSS J083011.35+383940.4   2.25500   9.3020  107.503763   350.462266
# 6   SDSS J213507.72-071655.6   2.25331   7.9122  126.387098   412.021941
# 7                   PHL 1266   2.24238   6.0652  164.875025   537.492581
# 8   SDSS J010442.19-084343.9   2.23809   8.0034  124.946898   407.326886
# 9   SDSS J135205.59+514930.5   2.23562   8.9041  112.307813   366.123471
# 10  SDSS J231629.37-093845.6   2.20085  10.1275   98.741052   321.895828
# 11  SDSS J222629.42+004254.1   2.19833   6.6263  150.913783   491.978932
# ...

# %%
#converting the column data into array
Star_Redshift=np.array(stars["Redshift"])
Star_dist_light_year=np.array(stars["Light Year"])

# %%
plt.figure(figsize=(12,8))
plt.scatter(Star_Redshift,Star_dist_light_year,color='red')
plt.title("Stars Along with their Redshift Values",fontsize=20)
plt.xlabel("Star Redshift Values",weight="bold")
plt.ylabel("Star Dist Light Year",weight="bold")
plt.legend(["Expanding Rate (z)"])
plt.savefig("Expanding universe_007")
plt.grid()
plt.show()

# %%
Star_Redshift
Star_dist_light_year
plt.figure(figsize=(12, 12))
plt.plot(Star_Redshift,Star_dist_light_year,label="Expanding Universe",linewidth=5,linestyle='--',marker='*',markeredgecolor="black",markersize=20,markerfacecolor='black')
plt.title("Behaviour of Stars's Redshift Values",fontsize=20)
plt.xlabel("Star Redshift Values",weight="bold")
plt.ylabel("Star Dist Light Year",weight="bold")
plt.legend(["Expanding Rate (z)"])
plt.savefig("Expanding universe_007")
plt.grid()
plt.show()
